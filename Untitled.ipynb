# %% [markdown]
# Hi, Thanks for coming in to my Github :) Please aware that this notebook will be mainly use for the Coursera Capstone Project for IBM!

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
